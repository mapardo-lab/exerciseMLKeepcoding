# %%
import os
import sys

os.chdir('..')
sys.path.append('src')

# %%
from utilsModel import TrainModels

models_trained = TrainModels()
models_trained.summary('medAE')
# Out:
#              model_name           date_train  \
# 0  MML_SVR_RBF_data1_T1  2025-12-13 10:28:31
#
#                           data_file      medAE
# 0  data/airbnb-listings-extract.csv  13.777004

# %%
from utilsModel import TrainModels

models_trained = TrainModels()

#models_trained.remove_model('MDL_fcnn_shallow_metadata1_T8')
# Out:
# Model MDL_fcnn_shallow_metadata1_T8 removed

# %%
import numpy as np
from utilsModel import TrainModels

models_trained = TrainModels()

model_name = "MML_SVR_RBF_data1_T1"
models_trained.info_model_results(model_name)
# Out:
# Model name: MML_SVR_RBF_data1_T1
# Date training: 2025-12-03 18:37:21
# rmse: 56.29
# medAE: 13.78
# r2: 0.32

# %%
import numpy as np
from utilsModel import TrainModels

models_trained = TrainModels()

model_name = "MML_SVR_RBF_data1_T1"
models_trained.info_model_summary(model_name)
# Out:
# Model name: MML_SVR_RBF_data1_T1
# Study: MML_SVR_RBF_data1
# Trial: 1
# Date training: 2025-12-13 10:28:31
# Data file: data/airbnb-listings-extract.csv
# Feature preprocessing: preprocess_features01
# Feature processing: ColumnTransformer(transformers=[('num',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(strategy='most_frequent')),
#                                                  ('scaler', StandardScaler())]),
#                                  ['Accommodates', 'Bathrooms']),
#                                 ('cat',
#                                  Pipeline(steps=[('target_enc',
#                                                   TargetEncoder(target_type='continuous')),
#                                                  ('scaler', StandardScaler())]),
#                                  ['Property Type', 'Cancellation Policy']),
#                                 ('ame', MultiLabelBinarizerWrapper(),
#                                  ['AmenitiesStr'])])
# Model: SVR(C=4.5705630998014515, gamma=0.09846738873614563)
# Hyperparameters: {'kernel': 'rbf', 'C': 4.5705630998014515, 'gamma': 0.09846738873614563}
# Model file: models/MML_SVR_RBF_data1_T1.pkl
